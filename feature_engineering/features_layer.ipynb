# %%
import pandas as pd

from gensim.models import CoherenceModel

# %% [markdown]
# Carregando modelo Doc2vec de reclamações

# %%
model = CoherenceModel.load('../model/doc2vec_claims')

# %% [markdown]
# Lendo base de dados de reclamações tratadas

# %%
rfzd_claims = pd.read_parquet('../dataset/refined/claims.parquet.snappy')

# %%
rfzd_claims.set_index('id', inplace=True)

# %% [markdown]
# Inferindo embeddings para cada reclamação

# %%
rfzd_claims['doc_embeddings'] = rfzd_claims['tokens_customer_claim'].apply(lambda tokens: model.infer_vector(tokens))

# %% [markdown]
# Ajustamento dataset para conter apenas o ID e os embeddings

# %%
frzd_claims = pd.DataFrame(rfzd_claims['doc_embeddings'].tolist(), index=rfzd_claims.index)

# %%
frzd_claims
# Out:
#                                                0         1         2    \
# id
# 4b286594b1bfaa6c60a7f729fa0746f48c612c5d -0.001155 -0.039674  0.265350
# ba6785160fd5e43eeed575fbcdbd2abf05935cfc -0.100346  0.142155 -0.090658
# f607b8cecea9c11da27a6fc45f9c1bc43c1f375e -0.016786  0.037815 -0.057893
# 04a82557dbde804b3ecf6fd357b91346c972e398 -0.221774 -0.220628 -0.016033
# a9ab2f2c4b24d64d90c2f5d00e0a85a4f5c187a4 -0.013266  0.029003  0.024088
# ...                                            ...       ...       ...
# 8cc3e46d81667f3906668ac04e8ebe0b70099c88 -0.079970  0.186568 -0.125528
# e35b701e491bb5fa96f3ab9be6c8561002344fd9  0.238397 -0.063829 -0.257273
# 77b002e25da07990cc3d2e8876d282730ac681dc  0.185348  0.048462  0.034870
# bf91d708e308e5d77f801862cca7ad487b6d4b19 -0.134822 -0.134560 -0.090740
# e89f76fcc376ba30dbbc283cb85ce5d1eefa7bf1 -0.005430  0.066734  0.031188
#
#                                                3         4         5    \
# id
# 4b286594b1bfaa6c60a7f729fa0746f48c612c5d  0.014326 -0.042130  0.021579
# ba6785160fd5e43eeed575fbcdbd2abf05935cfc -0.331412  0.030635 -0.096707
# f607b8cecea9c11da27a6fc45f9c1bc43c1f375e -0.008699  0.037505 -0.015799
# 04a82557dbde804b3ecf6fd357b91346c972e398 -0.081249  0.102747  0.080348
# a9ab2f2c4b24d64d90c2f5d00e0a85a4f5c187a4  0.025593  0.087337  0.096045
# ...                                            ...       ...       ...
# 8cc3e46d81667f3906668ac04e8ebe0b70099c88  0.238959 -0.092652  0.196215
# e35b701e491bb5fa96f3ab9be6c8561002344fd9 -0.057145  0.070478 -0.081230
# 77b002e25da07990cc3d2e8876d282730ac681dc -0.073727  0.157635 -0.080861
# bf91d708e308e5d77f801862cca7ad487b6d4b19  0.146373 -0.023016  0.184603
# e89f76fcc376ba30dbbc283cb85ce5d1eefa7bf1 -0.063053  0.010359  0.047940
#
#                                                6         7         8    \
# id
# 4b286594b1bfaa6c60a7f729fa0746f48c612c5d -0.160983  0.069715  0.176659
# ba6785160fd5e43eeed575fbcdbd2abf05935cfc  0.166541  0.091336 -0.073101
# f607b8cecea9c11da27a6fc45f9c1bc43c1f375e -0.004461 -0.043762  0.010009
# 04a82557dbde804b3ecf6fd357b91346c972e398 -0.118349 -0.078805 -0.043660
# a9ab2f2c4b24d64d90c2f5d00e0a85a4f5c187a4  0.091533 -0.091324  0.072656
# ...                                            ...       ...       ...
# 8cc3e46d81667f3906668ac04e8ebe0b70099c88  0.004616  0.069153 -0.094715
# e35b701e491bb5fa96f3ab9be6c8561002344fd9 -0.024700 -0.232757 -0.143417
# 77b002e25da07990cc3d2e8876d282730ac681dc  0.024770 -0.128983  0.077733
# bf91d708e308e5d77f801862cca7ad487b6d4b19 -0.040259 -0.110739 -0.098455
# e89f76fcc376ba30dbbc283cb85ce5d1eefa7bf1 -0.051817  0.000743 -0.047156
#
#                                                9    ...       390       391  \
# id                                                  ...
# 4b286594b1bfaa6c60a7f729fa0746f48c612c5d  0.031747  ... -0.183828  0.037753
# ba6785160fd5e43eeed575fbcdbd2abf05935cfc -0.138904  ...  0.138112  0.013840
# f607b8cecea9c11da27a6fc45f9c1bc43c1f375e -0.001889  ... -0.017820  0.026436
# 04a82557dbde804b3ecf6fd357b91346c972e398 -0.090957  ... -0.054378  0.049941
# a9ab2f2c4b24d64d90c2f5d00e0a85a4f5c187a4 -0.054545  ... -0.098941 -0.030491
# ...                                            ...  ...       ...       ...
# 8cc3e46d81667f3906668ac04e8ebe0b70099c88  0.095081  ...  0.124062 -0.150437
# e35b701e491bb5fa96f3ab9be6c8561002344fd9  0.041408  ...  0.101713  0.118697
# 77b002e25da07990cc3d2e8876d282730ac681dc -0.027338  ...  0.013893  0.012653
# bf91d708e308e5d77f801862cca7ad487b6d4b19  0.081044  ...  0.020637 -0.219160
# e89f76fcc376ba30dbbc283cb85ce5d1eefa7bf1  0.035952  ... -0.089115 -0.034239
#
#                                                392       393       394  \
# id
# 4b286594b1bfaa6c60a7f729fa0746f48c612c5d -0.221552 -0.087203 -0.014157
# ba6785160fd5e43eeed575fbcdbd2abf05935cfc -0.034270  0.073237 -0.320898
# f607b8cecea9c11da27a6fc45f9c1bc43c1f375e  0.034769  0.058025  0.025062
# 04a82557dbde804b3ecf6fd357b91346c972e398 -0.068399 -0.097254 -0.101845
# a9ab2f2c4b24d64d90c2f5d00e0a85a4f5c187a4 -0.032881 -0.022761 -0.112426
# ...                                            ...       ...       ...
# 8cc3e46d81667f3906668ac04e8ebe0b70099c88  0.016319 -0.049897 -0.019829
# e35b701e491bb5fa96f3ab9be6c8561002344fd9  0.040070  0.114010  0.024162
# 77b002e25da07990cc3d2e8876d282730ac681dc -0.006990 -0.019970  0.003077
# bf91d708e308e5d77f801862cca7ad487b6d4b19 -0.097163 -0.058470  0.104048
# e89f76fcc376ba30dbbc283cb85ce5d1eefa7bf1  0.023807  0.008001  0.111921
#
#                                                395       396       397  \
# id
# 4b286594b1bfaa6c60a7f729fa0746f48c612c5d -0.077501  0.249958 -0.041805
# ba6785160fd5e43eeed575fbcdbd2abf05935cfc -0.231775  0.106069  0.172888
# f607b8cecea9c11da27a6fc45f9c1bc43c1f375e -0.005733 -0.042851 -0.083232
# 04a82557dbde804b3ecf6fd357b91346c972e398 -0.024670  0.024136  0.050407
# a9ab2f2c4b24d64d90c2f5d00e0a85a4f5c187a4  0.071221 -0.086059 -0.138379
# ...                                            ...       ...       ...
# 8cc3e46d81667f3906668ac04e8ebe0b70099c88 -0.001319  0.243436 -0.013958
# e35b701e491bb5fa96f3ab9be6c8561002344fd9  0.008215  0.014421 -0.193731
# 77b002e25da07990cc3d2e8876d282730ac681dc -0.014641  0.077519 -0.093014
# bf91d708e308e5d77f801862cca7ad487b6d4b19 -0.051079  0.065751 -0.001143
# e89f76fcc376ba30dbbc283cb85ce5d1eefa7bf1  0.146120 -0.072709 -0.010739
#
#                                                398       399
# id
# 4b286594b1bfaa6c60a7f729fa0746f48c612c5d  0.107877 -0.025572
# ba6785160fd5e43eeed575fbcdbd2abf05935cfc -0.135818  0.214060
# f607b8cecea9c11da27a6fc45f9c1bc43c1f375e  0.033820 -0.017122
# 04a82557dbde804b3ecf6fd357b91346c972e398  0.037814 -0.046911
# a9ab2f2c4b24d64d90c2f5d00e0a85a4f5c187a4 -0.087535  0.030657
# ...                                            ...       ...
# 8cc3e46d81667f3906668ac04e8ebe0b70099c88  0.243590  0.183126
# e35b701e491bb5fa96f3ab9be6c8561002344fd9 -0.048711  0.189960
# 77b002e25da07990cc3d2e8876d282730ac681dc  0.030074  0.061006
# bf91d708e308e5d77f801862cca7ad487b6d4b19 -0.056943  0.038357
# e89f76fcc376ba30dbbc283cb85ce5d1eefa7bf1  0.034674 -0.022650
#
# [378574 rows x 400 columns]

# %% [markdown]
# Salvando dataset de embeddings como parquet

# %%
frzd_claims.to_parquet(
    path='../dataset/featured/claims.parquet.snappy',
    compression='snappy',
    index=True,
)
